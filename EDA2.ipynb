# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("OSD-457_DGE (1).csv")

# %%
df.dropna(inplace=True)

# %%
df['-LOG10_ADJP']= -np.log10(df['ADJP'])
# Out:
# C:\Users\Akshat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.reset_index(inplace=True)

# %%
a=[]
for i in range(0,df.shape[0]):
    if df['-LOG10_ADJP'][i]>1.30 and df['LOG2FC'][i]<= -1:
        a.append(1)
    elif df['-LOG10_ADJP'][i]<=1.30 and df['LOG2FC'][i]<=1:
        a.append(0)
    elif df['-LOG10_ADJP'][i]>1.30 and df['LOG2FC'][i]>1:

        a.append(2)
    else:
        a.append(3)

# %%
df['Class']=a

# %%
plt.scatter(y=df['-LOG10_ADJP'],x=df['LOG2FC'],c=df['Class'])

# %%
df['Class'].value_counts()
# Out:
# Class
# 1    6373
# 0    5440
# 3    4469
# 2    4214
# Name: count, dtype: int64

# %%
df[df['Class']==1 | df['Class']==2 | df['Class']==3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13428\2241926238.py in ?()
# ----> 1 df[df['Class']==1 | df['Class']==2 | df['Class']==3]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.shape[0]-5440
# Out:
# 15056

# %%
(15056/df.shape[0])*100
# Out:
# 73.45823575331772

# %%
l='navya'
for ele in l:
    print(ele)
# Out:
# n
# a
# v
# y
# a
