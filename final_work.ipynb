# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('earth-space30.csv').set_index('Symbol')

# %%
df2=pd.read_csv('earth-space60.csv').set_index('Symbol')

# %%
df3=pd.read_csv('All_space.csv').set_index('Symbol')
#'Slc12a1', 'Slc32a1'

# %%
df1_space30=df1.loc[['Cyp4f16', 'Cyp27a1', 'Cyp4f13', 'Cyp4v3', 'Cyp2e1', 'Cyp2d22', 'Cyp4b1', 'Cyp2b10', 'Cyp4f17', 'Cyp2u1', 'Cyp1a1', 'Cyp4f18', 'Cyp3a11', 'Cyp2f2', 'Cyp2ab1', 'Cyp2a12', 'Cyp2d10', 'Cyp2c29', 'Cyp2c70', 'Cyp1a2', 'Cyp2c50', 'Cyp4a14', 'Cyp4f41-ps', 'Cyp4a10', 'Cyp2d26', 'Cyp2c54']]

# %%
df2_space60=df2.loc[['Cyp4f16', 'Cyp27a1', 'Cyp4f13', 'Cyp4v3', 'Cyp2e1', 'Cyp2d22', 'Cyp4b1', 'Cyp2b10', 'Cyp4f17', 'Cyp2u1', 'Cyp1a1', 'Cyp4f18', 'Cyp3a11', 'Cyp2f2', 'Cyp2ab1', 'Cyp2a12', 'Cyp2d10', 'Cyp2c29', 'Cyp2c70', 'Cyp1a2', 'Cyp2c50', 'Cyp4a14', 'Cyp4f41-ps', 'Cyp4a10', 'Cyp2d26', 'Cyp2c54']]

# %%
df3_space30_60=df3.loc[['Cyp4f16', 'Cyp27a1', 'Cyp4f13', 'Cyp4v3', 'Cyp2e1', 'Cyp2d22', 'Cyp4b1', 'Cyp2b10', 'Cyp4f17', 'Cyp2u1', 'Cyp1a1', 'Cyp4f18', 'Cyp3a11', 'Cyp2f2', 'Cyp2ab1', 'Cyp2a12', 'Cyp2d10', 'Cyp2c29', 'Cyp2c70', 'Cyp1a2', 'Cyp2c50', 'Cyp4a14', 'Cyp4f41-ps', 'Cyp4a10', 'Cyp2d26', 'Cyp2c54']]

# %%
df1_space30['LOG2FC_30']=df1_space30['LOG2FC']

# %%
df1_space30.drop('LOG2FC', axis=1, inplace=True)

# %%
df1_space30['LOG2FC_60']=df2_space60['LOG2FC']
df1_space30['LOG2FC_30_60']=df3_space30_60['LOG2FC']

# %%
df1_space30[['LOG2FC_30','LOG2FC_60', 'LOG2FC_30_60']].plot(kind='bar')
plt.xlabel('Gene name')
plt.ylabel('LOG2FC')
plt.grid()
