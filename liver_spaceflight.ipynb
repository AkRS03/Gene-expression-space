# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('GLDS-457_rna_seq_Normalized_Counts.csv')

# %%
df1
# Out:
#                Unnamed: 0  GSM4613909  GSM4613910  GSM4613912   GSM4613911  \
# 0      ENSMUSG00000000001  531.799293  666.098956  472.376024   621.176539
# 1      ENSMUSG00000000028   66.896337   47.230064  102.910370   128.290282
# 2      ENSMUSG00000000031  455.825930  132.873284  551.667566  1583.564064
# 3      ENSMUSG00000000037   15.785661    6.471646   35.265835    24.095744
# 4      ENSMUSG00000000049   11.041964    8.028447    7.130210     8.389116
# ...                   ...         ...         ...         ...          ...
# 34456  ENSMUSG00002076954    0.000000    0.000000    0.000000     0.000000
# 34457  ENSMUSG00002076957    2.222151    0.000000    0.000000     0.733407
# 34458  ENSMUSG00002076967    0.000000    0.000000    0.000000     0.000000
# 34459  ENSMUSG00002076968    0.000000    0.000000    0.000000     0.000000
# 34460  ENSMUSG00002076983    0.000000    0.000000    0.000000     0.000000
#
# ...

# %%
df2=pd.read_csv('GLDS-457_rna_seq_SampleTable.csv')

# %%
k=[]
for i in range(0,6):
    ele='Liver_spaceflight_{i}'.format(i=i)
    k.append(ele)
for i in range(0,6):
    ele='Liver_groundcontrol_{i}'.format(i=i)
    k.append(ele)

# %%
df_values=df1[['GSM4613964','GSM4613961','GSM4613962','GSM4613963','GSM4613959','GSM4613966','GSM4613971','GSM4613973','GSM4613974','GSM4613975','GSM4613976','GSM4613978']]

# %%
plotting_df= pd.DataFrame(index=df1['Unnamed: 0'], columns=k)

# %%
plotting_df
# Out:
#                    Liver_spaceflight_0 Liver_spaceflight_1  \
# Unnamed: 0
# ENSMUSG00000000001                 NaN                 NaN
# ENSMUSG00000000028                 NaN                 NaN
# ENSMUSG00000000031                 NaN                 NaN
# ENSMUSG00000000037                 NaN                 NaN
# ENSMUSG00000000049                 NaN                 NaN
# ...                                ...                 ...
# ENSMUSG00002076954                 NaN                 NaN
# ENSMUSG00002076957                 NaN                 NaN
# ENSMUSG00002076967                 NaN                 NaN
# ENSMUSG00002076968                 NaN                 NaN
# ENSMUSG00002076983                 NaN                 NaN
#
#                    Liver_spaceflight_2 Liver_spaceflight_3  \
# Unnamed: 0
# ENSMUSG00000000001                 NaN                 NaN
# ENSMUSG00000000028                 NaN                 NaN
# ...

# %%
df3=pd.read_csv('WT-GC-SF.csv')

# %%
df3
# Out:
#                   ENSEMBL    Symbol     LOG2FC          PVAL          ADJP
# 0      ENSMUSG00000011118     Panx3  19.101743  2.512807e-11  5.843195e-09
# 1      ENSMUSG00000013418  B4galnt2 -15.255694  4.069233e-15  1.007690e-12
# 2      ENSMUSG00000028834    Trim63 -11.926390  1.512613e-14  3.650951e-12
# 3      ENSMUSG00000030827     Fgf21  -4.566293  2.979864e-15  7.476321e-13
# 4      ENSMUSG00000031383     Dusp9  -9.322874  7.276249e-14  1.734294e-11
# ...                   ...       ...        ...           ...           ...
# 34456  ENSMUSG00002076907       NaN   0.000000  1.000000e+00           NaN
# 34457  ENSMUSG00002076945       NaN   0.000000  1.000000e+00           NaN
# 34458  ENSMUSG00002076957       NaN   0.000000  1.000000e+00           NaN
# 34459  ENSMUSG00002076967       NaN   0.000000  1.000000e+00           NaN
# 34460  ENSMUSG00002076983       NaN   0.000000  1.000000e+00           NaN
#
# [34461 rows x 5 columns]

# %%
mask1=abs(df3['LOG2FC'])>1
mask2=df3['PVAL']<0.05

# %%
df3[mask1&mask2]
# Out:
#                  ENSEMBL    Symbol     LOG2FC          PVAL          ADJP
# 0     ENSMUSG00000011118     Panx3  19.101743  2.512807e-11  5.843195e-09
# 1     ENSMUSG00000013418  B4galnt2 -15.255694  4.069233e-15  1.007690e-12
# 2     ENSMUSG00000028834    Trim63 -11.926390  1.512613e-14  3.650951e-12
# 3     ENSMUSG00000030827     Fgf21  -4.566293  2.979864e-15  7.476321e-13
# 4     ENSMUSG00000031383     Dusp9  -9.322874  7.276249e-14  1.734294e-11
# ...                  ...       ...        ...           ...           ...
# 2382  ENSMUSG00000032186     Tmod2   1.402202  4.948837e-02  4.203676e-01
# 2385  ENSMUSG00000034023    Fancd2   1.329469  4.957036e-02  4.203676e-01
# 2388  ENSMUSG00000027560      Dok5   2.225217  4.961971e-02  4.203676e-01
# 2389  ENSMUSG00000087142       NaN   1.185362  4.962489e-02  4.203676e-01
# 2392  ENSMUSG00000109714       NaN   1.867758  4.984006e-02           NaN
#
# [765 rows x 5 columns]

# %%
df3
# Out:
#                   ENSEMBL    Symbol     LOG2FC          PVAL          ADJP
# 0      ENSMUSG00000011118     Panx3  19.101743  2.512807e-11  5.843195e-09
# 1      ENSMUSG00000013418  B4galnt2 -15.255694  4.069233e-15  1.007690e-12
# 2      ENSMUSG00000028834    Trim63 -11.926390  1.512613e-14  3.650951e-12
# 3      ENSMUSG00000030827     Fgf21  -4.566293  2.979864e-15  7.476321e-13
# 4      ENSMUSG00000031383     Dusp9  -9.322874  7.276249e-14  1.734294e-11
# ...                   ...       ...        ...           ...           ...
# 34456  ENSMUSG00002076907       NaN   0.000000  1.000000e+00           NaN
# 34457  ENSMUSG00002076945       NaN   0.000000  1.000000e+00           NaN
# 34458  ENSMUSG00002076957       NaN   0.000000  1.000000e+00           NaN
# 34459  ENSMUSG00002076967       NaN   0.000000  1.000000e+00           NaN
# 34460  ENSMUSG00002076983       NaN   0.000000  1.000000e+00           NaN
#
# [34461 rows x 5 columns]

# %%
cyp_indices = df3[df3['Symbol'].str[:3] == 'Cyp'].index.to_list()

# %%
df_to_use=df3.iloc[cyp_indices]

# %%
df_to_use.reset_index(inplace=True)

# %%
a=[]
for i in range(0,df_to_use.shape[0]):
    if df_to_use['LOG2FC'][i]<-1:
        a.append(1)
    elif df_to_use['LOG2FC'][i]<=1:
        a.append(0)
    elif df_to_use['LOG2FC'][i]>1:

        a.append(2)
    else:
        a.append(0)

# %%
df_to_use['Class']=a
# Out:
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_14540\3799967705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_to_use['Class']=a

# %%
df_to_use
# Out:
#      index             ENSEMBL      Symbol    LOG2FC      PVAL      ADJP  \
# 0      159  ENSMUSG00000039519      Cyp7b1  1.075273  0.000010  0.001284
# 1      229  ENSMUSG00000015224      Cyp2j9 -0.749171  0.000100  0.008525
# 2      251  ENSMUSG00000074254      Cyp2a4  4.030309  0.000147  0.011431
# 3      272  ENSMUSG00000025002     Cyp2c55  1.837703  0.000216  0.015477
# 4      286  ENSMUSG00000049439     Cyp20a1  0.457262  0.000280  0.019089
# ..     ...                 ...         ...       ...       ...       ...
# 99   28029  ENSMUSG00000081225     Cyp2j12  0.000000  1.000000       NaN
# 100  28050  ENSMUSG00000081362      Cyp2j7  0.000000  1.000000       NaN
# 101  28354  ENSMUSG00000084286  Cyp2j15-ps  0.000000  1.000000       NaN
# 102  28886  ENSMUSG00000086896    Cyp4x1os  0.000000  1.000000       NaN
# 103  29265  ENSMUSG00000090700     Cyp4f40  0.000000  1.000000       NaN
#
#      Class
# 0        2
# 1        0
# 2        2
# 3        2
# 4        0
# ..     ...
# ...

# %%
mask3=df_to_use['Class']==2
mask4=df_to_use['Class']==1

# %%
df_for_use=df_to_use[mask3|mask4]

# %%
df_for_use.reset_index(inplace=True)

# %%
df_for_use=df_for_use.iloc[:,2:]

# %%
df_for_use
# Out:
#                ENSEMBL      Symbol    LOG2FC      PVAL      ADJP  Class
# 0   ENSMUSG00000039519      Cyp7b1  1.075273  0.000010  0.001284      2
# 1   ENSMUSG00000074254      Cyp2a4  4.030309  0.000147  0.011431      2
# 2   ENSMUSG00000025002     Cyp2c55  1.837703  0.000216  0.015477      2
# 3   ENSMUSG00000003555     Cyp17a1  1.171544  0.006060  0.141437      2
# 4   ENSMUSG00000028715     Cyp4a14 -2.048983  0.016111  0.250167      1
# 5   ENSMUSG00000082932      Cyp2j8 -1.834386  0.021907       NaN      1
# 6   ENSMUSG00000030483     Cyp2b10 -1.333675  0.034912  0.360023      1
# 7   ENSMUSG00000032808     Cyp2c38 -1.394449  0.042823  0.392946      1
# 8   ENSMUSG00000060613     Cyp2c70  1.211463  0.094890  0.557244      2
# 9   ENSMUSG00000022818     Cyp2ab1 -1.087690  0.395484  0.901372      1
# 10  ENSMUSG00000040660      Cyp2b9 -1.237685  0.592251  0.987678      1
# 11  ENSMUSG00000091867     Cyp2a22 -2.039363  0.615783  0.995390      1
# ...

# %%
df=pd.read_csv('GLDS-457_rna_seq_Normalized_Counts.csv').set_index('Unnamed: 0').loc[df_for_use['ENSEMBL'].to_list()]

# %%
df
# Out:
#                     GSM4613909  GSM4613910  GSM4613912  GSM4613911  \
# Unnamed: 0
# ENSMUSG00000039519   41.477509   67.169737   33.265909   29.335415
# ENSMUSG00000074254    0.000000    0.000000    0.000000    0.000000
# ENSMUSG00000025002    0.000000    1.399370    0.739242    2.200157
# ENSMUSG00000003555    0.000000    0.537362    0.000000    0.000000
# ENSMUSG00000028715    6.034887    4.871846    8.724668    1.195108
# ENSMUSG00000082932    2.222018    4.897802    0.739242    2.200160
# ENSMUSG00000030483   12.900692    7.294911   30.874138   86.925592
# ENSMUSG00000032808    0.740668    0.000000    0.000000    0.000000
# ENSMUSG00000060613    4.598040    2.253427    6.804884    1.517604
# ENSMUSG00000022818    1.333624    1.192145    8.155895    7.486966
# ENSMUSG00000040660    0.000000    0.000000    0.000000    0.000000
# ENSMUSG00000091867    0.000000    0.000000    0.000000    1.032366
# ENSMUSG00000054417    0.000000    0.000000    0.000000    0.000000
# ...

# %%
df_all_exp=df.loc[df_for_use['ENSEMBL']]

# %%
df_liver_exp=df_all_exp[df_values.columns.to_list()]

# %%
df_liver_exp.shape
# Out:
# (20, 12)

# %%
plotting_df=plotting_df.loc[df_for_use['ENSEMBL']]

# %%
for i in range(0,12):
    plotting_df.iloc[:,i]=df_liver_exp.iloc[:,i]

# %%
df_liver_exp
# Out:
#                       GSM4613964    GSM4613961    GSM4613962    GSM4613963  \
# Unnamed: 0
# ENSMUSG00000039519   2072.252328   1935.872357   2286.595647   3559.545611
# ENSMUSG00000074254     47.399791     63.575670     19.990507     18.207481
# ENSMUSG00000025002     13.331161     31.787762     27.679078     57.656844
# ENSMUSG00000003555    102.617398    128.132841    113.693992     79.068824
# ENSMUSG00000028715  33662.267949  30295.603279  31807.492081  16688.410075
# ENSMUSG00000082932      1.481247      7.946980      4.613211      7.586478
# ENSMUSG00000030483    345.223690    151.246680    732.082334    295.488313
# ENSMUSG00000032808   3107.627205   3914.644704   3106.188162   2356.329373
# ENSMUSG00000060613   4071.494290   4388.604749   5427.683538   6294.857978
# ENSMUSG00000022818      0.000000      5.830281      0.000000      0.000000
# ENSMUSG00000040660    127.386770     20.662066     56.895958     15.172874
# ...

# %%
plotting_df
# Out:
#                    Liver_spaceflight_0 Liver_spaceflight_1  \
# Unnamed: 0
# ENSMUSG00000039519         2072.252328         1935.872357
# ENSMUSG00000074254           47.399791            63.57567
# ENSMUSG00000025002           13.331161           31.787762
# ENSMUSG00000003555          102.617398          128.132841
# ENSMUSG00000028715        33662.267949        30295.603279
# ENSMUSG00000082932            1.481247             7.94698
# ENSMUSG00000030483           345.22369           151.24668
# ENSMUSG00000032808         3107.627205         3914.644704
# ENSMUSG00000060613          4071.49429         4388.604749
# ENSMUSG00000022818                 0.0            5.830281
# ENSMUSG00000040660           127.38677           20.662066
# ENSMUSG00000091867          403.524977          287.526644
# ENSMUSG00000054417                 0.0            1.589389
# ENSMUSG00000070419                 0.0            4.156001
# ENSMUSG00000094559            1.297678            1.392424
# ...

# %%
df_for_use
# Out:
#                ENSEMBL      Symbol    LOG2FC      PVAL      ADJP  Class
# 0   ENSMUSG00000039519      Cyp7b1  1.075273  0.000010  0.001284      2
# 1   ENSMUSG00000074254      Cyp2a4  4.030309  0.000147  0.011431      2
# 2   ENSMUSG00000025002     Cyp2c55  1.837703  0.000216  0.015477      2
# 3   ENSMUSG00000003555     Cyp17a1  1.171544  0.006060  0.141437      2
# 4   ENSMUSG00000028715     Cyp4a14 -2.048983  0.016111  0.250167      1
# 5   ENSMUSG00000082932      Cyp2j8 -1.834386  0.021907       NaN      1
# 6   ENSMUSG00000030483     Cyp2b10 -1.333675  0.034912  0.360023      1
# 7   ENSMUSG00000032808     Cyp2c38 -1.394449  0.042823  0.392946      1
# 8   ENSMUSG00000060613     Cyp2c70  1.211463  0.094890  0.557244      2
# 9   ENSMUSG00000022818     Cyp2ab1 -1.087690  0.395484  0.901372      1
# 10  ENSMUSG00000040660      Cyp2b9 -1.237685  0.592251  0.987678      1
# 11  ENSMUSG00000091867     Cyp2a22 -2.039363  0.615783  0.995390      1
# ...

# %%
plotting_df_final=plotting_df.T

# %%
plotting_df_final
# Out:
# Unnamed: 0            ENSMUSG00000039519 ENSMUSG00000074254  \
# Liver_spaceflight_0          2072.252328          47.399791
# Liver_spaceflight_1          1935.872357           63.57567
# Liver_spaceflight_2          2286.595647          19.990507
# Liver_spaceflight_3          3559.545611          18.207481
# Liver_spaceflight_4          5840.149538          82.604849
# Liver_spaceflight_5          2604.038138          14.621247
# Liver_groundcontrol_0        9634.232693          64.670636
# Liver_groundcontrol_1        6064.733098          41.528474
# Liver_groundcontrol_2        5691.732706          43.882839
# Liver_groundcontrol_3        7526.441941          19.200198
# Liver_groundcontrol_4        3154.848968        3837.399435
# Liver_groundcontrol_5        6483.290816          17.131044
#
# Unnamed: 0            ENSMUSG00000025002 ENSMUSG00000003555  \
# Liver_spaceflight_0            13.331161         102.617398
# Liver_spaceflight_1            31.787762         128.132841
# ...

# %%
plotting_df_2=pd.DataFrame(index=plotting_df_final.index,columns=df_for_use['Symbol'])

# %%
for i in range(0,plotting_df_2.shape[1]):
    plotting_df_2.iloc[:,i]=plotting_df_final.iloc[:,i].values

# %%
plotting_df_2.shape
# Out:
# (12, 20)

# %%
start_value=-0.2
increment=1
start_value2=0.05
increment2=1

# %%
plotting_df_2.iloc[:6,1].values
# Out:
# array([47.3997907653335, 63.5756700691291, 19.990507285598,
#        18.2074807478933, 82.6048494677927, 14.6212469218616], dtype=object)

# %%
l=[]
for i in range(0,20):
    l.append(np.mean(plotting_df_2.iloc[:,i].values[0:6]))
k=[]
for i in range(0,20):
    k.append(np.mean(plotting_df_2.iloc[:,i].values[6:12]))

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
values
# Out:
# [array([0.32248537, 0.30126183, 0.35584163, 0.55393901, 0.90884821,
#         0.40524226]),
#  array([0.07067892, 0.09479915, 0.02980831, 0.0271496 , 0.123174  ,
#         0.02180208]),
#  array([0.12226876, 0.29154628, 0.25386287, 0.52880849, 0.22728654,
#         0.25479149]),
#  array([0.44488866, 0.55550861, 0.49291025, 0.3427959 , 0.26866299,
#         0.5575497 ]),
#  array([5.21862928, 4.69669847, 4.93108515, 2.58718829, 3.50263169,
#         3.89265673]),
#  array([0.94360339, 5.06248797, 2.93876713, 4.83283617, 3.15732602,
#         4.65711595]),
#  array([2.27904439, 0.99847695, 4.83294798, 1.95070907, 2.68665722,
#         2.37654316]),
#  array([2.94673787, 3.71197413, 2.94537333, 2.23433653, 1.68874832,
#         2.24600157]),
#  array([0.3444821 , 0.37131227, 0.45922693, 0.53259706, 0.56794795,
#         0.31542059]),
#  array([nan, inf, nan, nan, nan, nan]),
#  array([4.80133299, 0.77877363, 2.14446477, 0.57188057, 5.85329648,
#         0.        ]),
# ...

# %%
1/2
# Out:
# 0.5

# %%
k
# Out:
# [6425.88003700507,
#  670.6354376077933,
#  109.03161453722532,
#  230.6586055082771,
#  6450.404147788885,
#  1.5697775943935885,
#  151.4773873626313,
#  1054.5991348803454,
#  11819.175260410171,
#  0.0,
#  26.531542514401895,
#  57.2830048246142,
#  7.147946931509093,
#  1.4419049707998368,
#  2.0188442962660647,
#  0.0,
#  0.5333375672041466,
#  24.969746592394998,
#  0.0,
#  2.070442757797002]

# %%
l
# Out:
# [3049.742269926897,
#  41.06659087626804,
#  30.50276499364671,
#  102.3476869266927,
#  26692.728745024968,
#  5.649142050510832,
#  381.83356360253566,
#  2772.395547103442,
#  5103.888023961709,
#  0.9717134591661284,
#  62.56910870761573,
#  235.48112777995652,
#  2.549340982395265,
#  3.04504968228874,
#  0.6728781730327834,
#  2.7250169705835248,
#  0.0,
#  6.407151705418285,
#  0.7847351139858884,
#  0.7845198020526182]

# %%
fig=plt.figure(figsize=(10,7))
ax=fig.add_axes([0,0,1,1])
values=[]
for i in range(0,20):
    values.append(list(plotting_df_2.iloc[:,i].values[0:6])/k[i])
values2=[]
for i in range(0,20):
    values2.append(list(plotting_df_2.iloc[:,i].values[6:])/k[i])


bp1=ax.boxplot(values, positions=np.arange(0,20)-0.2, widths=0.2)
sc=plt.scatter([[start_value + i * increment] * 6 for i in range(20)],values, marker='o' ,color='green',label='Space_flight',alpha=0.5)
bp2= ax.boxplot(values2, positions=np.arange(0,20)+0.05, widths=0.2)
sc2=plt.scatter([[start_value2 + i * increment2] * 6 for i in range(20)],values2, marker='o' ,color='red',label='Ground_control',alpha=0.5)
plt.xticks(np.arange(20)-0.125, plotting_df_2.columns) 
plt.xticks(rotation='vertical')
plt.legend()

plt.show()
# Out:
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_14540\188949425.py:5: RuntimeWarning: divide by zero encountered in divide
#   values.append(list(plotting_df_2.iloc[:,i].values[0:6])/k[i])
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_14540\188949425.py:5: RuntimeWarning: invalid value encountered in divide
#   values.append(list(plotting_df_2.iloc[:,i].values[0:6])/k[i])
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_14540\188949425.py:8: RuntimeWarning: invalid value encountered in divide
#   values2.append(list(plotting_df_2.iloc[:,i].values[6:])/k[i])

# %%
fig=plt.figure(figsize=(10,7))
ax=fig.add_axes([0,0,1,1])
values=[]
for i in range(0,20):
    values.append(list(plotting_df_2.iloc[:,i].values[0:6])/k[i])
values2=[]
for i in range(0,20):
    values2.append(list(plotting_df_2.iloc[:,i].values[6:])/k[i])


bp1=ax.boxplot(values,positions=np.arange(0,20)-0.2,widths=0.2)
sc=plt.scatter([[start_value + i * increment] * 6 for i in range(20)],values, marker='o' ,color='green',label='Space_flight',alpha=0.5)
bp2=ax.boxplot(values2,positions=np.arange(0,20)+0.05,widths=0.2)
sc2=plt.scatter([[start_value2 + i * increment2] * 6 for i in range(20)],values2, marker='o' ,color='red',label='Ground_control',alpha=0.5)
plt.xticks(np.arange(20)-0.125, plotting_df_2.columns) 
plt.xticks(rotation='vertical')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_14540\2930673211.py:5: RuntimeWarning: divide by zero encountered in divide
#   values.append(list(plotting_df_2.iloc[:,i].values[0:6])/k[i])
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_14540\2930673211.py:5: RuntimeWarning: invalid value encountered in divide
#   values.append(list(plotting_df_2.iloc[:,i].values[0:6])/k[i])
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_14540\2930673211.py:8: RuntimeWarning: invalid value encountered in divide
#   values2.append(list(plotting_df_2.iloc[:,i].values[6:])/k[i])

# %%
df
# Out:
#                     GSM4613909  GSM4613910  GSM4613912  GSM4613911  \
# Unnamed: 0
# ENSMUSG00000039519   41.477509   67.169737   33.265909   29.335415
# ENSMUSG00000074254    0.000000    0.000000    0.000000    0.000000
# ENSMUSG00000025002    0.000000    1.399370    0.739242    2.200157
# ENSMUSG00000003555    0.000000    0.537362    0.000000    0.000000
# ENSMUSG00000028715    6.034887    4.871846    8.724668    1.195108
# ENSMUSG00000082932    2.222018    4.897802    0.739242    2.200160
# ENSMUSG00000030483   12.900692    7.294911   30.874138   86.925592
# ENSMUSG00000032808    0.740668    0.000000    0.000000    0.000000
# ENSMUSG00000060613    4.598040    2.253427    6.804884    1.517604
# ENSMUSG00000022818    1.333624    1.192145    8.155895    7.486966
# ENSMUSG00000040660    0.000000    0.000000    0.000000    0.000000
# ENSMUSG00000091867    0.000000    0.000000    0.000000    1.032366
# ENSMUSG00000054417    0.000000    0.000000    0.000000    0.000000
# ...

# %%
df
# Out:
#                     GSM4613909  GSM4613910  GSM4613912  GSM4613911  \
# Unnamed: 0
# ENSMUSG00000039519   41.477509   67.169737   33.265909   29.335415
# ENSMUSG00000074254    0.000000    0.000000    0.000000    0.000000
# ENSMUSG00000025002    0.000000    1.399370    0.739242    2.200157
# ENSMUSG00000003555    0.000000    0.537362    0.000000    0.000000
# ENSMUSG00000028715    6.034887    4.871846    8.724668    1.195108
# ENSMUSG00000082932    2.222018    4.897802    0.739242    2.200160
# ENSMUSG00000030483   12.900692    7.294911   30.874138   86.925592
# ENSMUSG00000032808    0.740668    0.000000    0.000000    0.000000
# ENSMUSG00000060613    4.598040    2.253427    6.804884    1.517604
# ENSMUSG00000022818    1.333624    1.192145    8.155895    7.486966
# ENSMUSG00000040660    0.000000    0.000000    0.000000    0.000000
# ENSMUSG00000091867    0.000000    0.000000    0.000000    1.032366
# ENSMUSG00000054417    0.000000    0.000000    0.000000    0.000000
# ...
